# %%
import pandas as pd

filename = 'need_public_use_file_2014.csv'
df = pd.read_csv(filename)

# %%
df.head(20)
# Out:
#     HH_ID     REGION  IMD_ENG  IMD_WALES  Gcons2005 Gcons2005Valid  Gcons2006  \
# 0       1  E12000007      1.0        NaN    35000.0              V    24500.0
# 1       2  E12000002      4.0        NaN    19000.0              V    14900.0
# 2       3  E12000002      4.0        NaN    22500.0              V    22500.0
# 3       4  E12000005      1.0        NaN    21000.0              V    20500.0
# 4       5  E12000003      1.0        NaN        NaN              M        NaN
# 5       6  E12000007      2.0        NaN        NaN              O        NaN
# 6       7  E12000006      3.0        NaN    12000.0              V    16500.0
# 7       8  E12000005      5.0        NaN    18500.0              V    15500.0
# 8       9  E12000007      4.0        NaN    35000.0              V    40000.0
# 9      10  E12000003      2.0        NaN    28000.0              V    26000.0
# 10     11  E12000007      2.0        NaN     1000.0              V    35000.0
# 11     12  E12000007      1.0        NaN        NaN              M        NaN
# 12     13  E12000006      5.0        NaN        NaN              M        NaN
# 13     14  E12000004      1.0        NaN    23500.0              V    26000.0
# 14     15  E12000002      4.0        NaN    14800.0              V    14000.0
# 15     16  E12000006      1.0        NaN    26000.0              V    23000.0
# 16     17  E12000001      2.0        NaN    19000.0              V    22000.0
# 17     18  E12000008      3.0        NaN        NaN              O        NaN
# 18     19  E12000009      2.0        NaN    15200.0              V    12300.0
# 19     20  E12000008      4.0        NaN        NaN              M    22500.0
#
#    Gcons2006Valid  Gcons2007 Gcons2007Valid     ...      FLOOR_AREA_BAND  \
# 0               V    22000.0              V     ...                    4
# 1               V    16000.0              V     ...                    2
# 2               V    22500.0              V     ...                    4
# 3               V    18000.0              V     ...                    3
# 4               M        NaN              M     ...                    1
# 5               O        NaN              O     ...                    1
# 6               V    12300.0              V     ...                    2
# 7               V    13900.0              V     ...                    4
# 8               V    35000.0              V     ...                    3
# 9               V    24000.0              V     ...                    3
# 10              V    35000.0              V     ...                    2
# 11              M        NaN              M     ...                    1
# 12              M        NaN              M     ...                    3
# 13              V    22000.0              V     ...                    2
# 14              V    15700.0              V     ...                    2
# 15              V    21000.0              V     ...                    2
# 16              V    23500.0              V     ...                    2
# 17              O        NaN              O     ...                    3
# 18              V    12900.0              V     ...                    3
# 19              V    22500.0              V     ...                    4
#
#    EE_BAND  LOFT_DEPTH WALL_CONS  CWI CWI_YEAR   LI LI_YEAR  BOILER  \
# 0        3           2         2  NaN      NaN  NaN     NaN     NaN
# 1        4           2         2  NaN      NaN  NaN     NaN     NaN
# 2        3           2         1  NaN      NaN  NaN     NaN     1.0
# 3        4           2         2  NaN      NaN  NaN     NaN     NaN
# 4        2          99         2  NaN      NaN  NaN     NaN     NaN
# 5        1          99         1  NaN      NaN  NaN     NaN     NaN
# 6        4           2         1  NaN      NaN  NaN     NaN     NaN
# 7        3           2         1  NaN      NaN  NaN     NaN     NaN
# 8        3           1         1  NaN      NaN  NaN     NaN     NaN
# 9        3           2         1  NaN      NaN  1.0  2009.0     NaN
# 10       3           1         2  NaN      NaN  NaN     NaN     NaN
# 11       3          99         1  NaN      NaN  NaN     NaN     NaN
# 12       6           1         2  NaN      NaN  NaN     NaN     NaN
# 13       4           2         1  NaN      NaN  NaN     NaN     1.0
# 14       3           2         1  1.0   2010.0  1.0  2012.0     1.0
# 15       3           2         1  1.0   2009.0  1.0  2009.0     1.0
# 16       4          99         2  NaN      NaN  NaN     NaN     NaN
# 17       3           2         1  1.0   2007.0  1.0  2007.0     NaN
# 18       3           2         1  1.0   2006.0  1.0  2011.0     NaN
# 19       2           2         1  NaN      NaN  NaN     NaN     NaN
#
#    BOILER_YEAR
# 0          NaN
# 1          NaN
# 2       2004.0
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13      2007.0
# 14      2012.0
# 15      2005.0
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
#
# [20 rows x 50 columns]

# %%
# keep only london region entries

london = 'E12000007'
df = df[df.REGION==london]

# drop the region column, and index for wales
df = df.drop(columns=['REGION', 'IMD_WALES'])
df.head()
# Out:
#     HH_ID  IMD_ENG  Gcons2005 Gcons2005Valid  Gcons2006 Gcons2006Valid  \
# 0       1      1.0    35000.0              V    24500.0              V
# 5       6      2.0        NaN              O        NaN              O
# 8       9      4.0    35000.0              V    40000.0              V
# 10     11      2.0     1000.0              V    35000.0              V
# 11     12      1.0        NaN              M        NaN              M
#
#     Gcons2007 Gcons2007Valid  Gcons2008 Gcons2008Valid     ...      \
# 0     22000.0              V    25000.0              V     ...
# 5         NaN              O        NaN              O     ...
# 8     35000.0              V    35000.0              V     ...
# 10    35000.0              V    22500.0              V     ...
# 11        NaN              M        NaN              M     ...
#
#     FLOOR_AREA_BAND EE_BAND  LOFT_DEPTH WALL_CONS  CWI CWI_YEAR  LI LI_YEAR  \
# 0                 4       3           2         2  NaN      NaN NaN     NaN
# 5                 1       1          99         1  NaN      NaN NaN     NaN
# 8                 3       3           1         1  NaN      NaN NaN     NaN
# 10                2       3           1         2  NaN      NaN NaN     NaN
# 11                1       3          99         1  NaN      NaN NaN     NaN
#
#     BOILER BOILER_YEAR
# 0      NaN         NaN
# 5      NaN         NaN
# 8      NaN         NaN
# 10     NaN         NaN
# 11     NaN         NaN
#
# [5 rows x 48 columns]

# %%
# select all the headings containing 'gcons', 'econs', and 'valid' using list comprehension
colhead = df.columns
gcons = [c for c in colheads if ('Gcons' in c) & ('Valid' not in c)]
econs = [c for c in colheads if ('Econs' in c) & ('Valid' not in c)]

# %%
# use the remaining headings as identifiers (dropping the validation columns and instead manually drop NaN entries and consumption that are out of range)
colheads_keep1 = [x for x in colheads if ('Gcons' not in x) & ('Valid' not in x)]

df1 = pd.melt(df, id_vars=colheads_keep1, value_vars=gcons, var_name='col_name', value_name='gcons')
df1 = df1[(df1.gcons.notnull()) | ((df1.gcons > 100) & (df1.gcons<50000))]

# keep only year part of col_name and save as new column
df1['year'] = df1.col_name.astype(str).str[5:9]
df1 = df1.drop(columns='col_name')

df1.head()
# Out:
#    HH_ID  IMD_ENG  Econs2005  Econs2006  Econs2007  Econs2008  Econs2009  \
# 0      1      1.0    12500.0    10900.0    12500.0    11000.0     9500.0
# 2      9      4.0    10300.0     7700.0    14500.0     6000.0     5650.0
# 3     11      2.0     4300.0     5400.0     3600.0     3500.0     3600.0
# 5     36      4.0     5800.0     6250.0     4900.0     6350.0     6250.0
# 7     57      5.0     2450.0     2650.0     2800.0     3600.0     3300.0
#
#    Econs2010  Econs2011  Econs2012  ...   LOFT_DEPTH  WALL_CONS  CWI  \
# 0    10000.0       7600     6300.0  ...            2          2  NaN
# 2     3050.0       3850     4400.0  ...            1          1  NaN
# 3     3250.0       3900     5150.0  ...            1          2  NaN
# 5     6750.0       6300     7950.0  ...            2          2  NaN
# 7     3200.0       3250     1550.0  ...            2          2  1.0
#
#    CWI_YEAR  LI  LI_YEAR  BOILER  BOILER_YEAR    gcons  year
# 0       NaN NaN      NaN     NaN          NaN  35000.0  2005
# 2       NaN NaN      NaN     NaN          NaN  35000.0  2005
# 3       NaN NaN      NaN     NaN          NaN   1000.0  2005
# 5       NaN NaN      NaN     NaN          NaN  35000.0  2005
# 7    2012.0 NaN      NaN     NaN          NaN  15900.0  2005
#
# [5 rows x 26 columns]

# %%
# save melted electricity consumption as new dataframe then merge with df1
df_econs = pd.melt(df1, id_vars='HH_ID', value_vars=econs, var_name='col_name', value_name='econs')
df_econs = df_econs[(df_econs.econs.notnull()) | ((df_econs.econs>100) & (df_econs.econs<50000))]
df_econs['year'] = df_econs.col_name.astype(str).str[5:9]
df_econs = df_econs.drop(columns='col_name')
df_econs.head()
# Out:
#    HH_ID    econs  year
# 0      1  12500.0  2005
# 1      9  10300.0  2005
# 2     11   4300.0  2005
# 3     36   5800.0  2005
# 4     57   2450.0  2005

# %%
# drop econs columns in gas consumption dataframe then merge on HHID and year
df1 = df1.drop(columns=econs)

ldn = df1.merge(df_econs, how='inner', left_on=['HH_ID', 'year'], right_on=['HH_ID', 'year'])
ldn.drop_duplicates(inplace=True)
ldn = ldn.sort_values(by='HH_ID')
ldn = ldn.reset_index(drop=True)
ldn.head()
# Out:
#    HH_ID  IMD_ENG  E7Flag2012  MAIN_HEAT_FUEL  PROP_AGE  PROP_TYPE  \
# 0      1      1.0         NaN               1       101        104
# 1      1      1.0         NaN               1       101        104
# 2      1      1.0         NaN               1       101        104
# 3      1      1.0         NaN               1       101        104
# 4      1      1.0         NaN               1       101        104
#
#    FLOOR_AREA_BAND  EE_BAND  LOFT_DEPTH  WALL_CONS  CWI  CWI_YEAR  LI  \
# 0                4        3           2          2  NaN       NaN NaN
# 1                4        3           2          2  NaN       NaN NaN
# 2                4        3           2          2  NaN       NaN NaN
# 3                4        3           2          2  NaN       NaN NaN
# 4                4        3           2          2  NaN       NaN NaN
#
#    LI_YEAR  BOILER  BOILER_YEAR    gcons  year    econs
# 0      NaN     NaN          NaN  35000.0  2005  12500.0
# 1      NaN     NaN          NaN  22000.0  2007  12500.0
# 2      NaN     NaN          NaN  25000.0  2008  11000.0
# 3      NaN     NaN          NaN  23000.0  2009   9500.0
# 4      NaN     NaN          NaN  20000.0  2010  10000.0

# %%
ldn.dtypes
# Out:
# HH_ID                int64
# IMD_ENG            float64
# E7Flag2012         float64
# MAIN_HEAT_FUEL       int64
# PROP_AGE             int64
# PROP_TYPE            int64
# FLOOR_AREA_BAND      int64
# EE_BAND              int64
# LOFT_DEPTH           int64
# WALL_CONS            int64
# CWI                float64
# CWI_YEAR           float64
# LI                 float64
# LI_YEAR            float64
# BOILER             float64
# BOILER_YEAR        float64
# gcons              float64
# year                object
# econs              float64
# dtype: object

# %%
# convert year column from object to int
ldn['year'] = pd.to_numeric(ldn.year)
ldn.dtypes
# Out:
# HH_ID                int64
# IMD_ENG            float64
# E7Flag2012         float64
# MAIN_HEAT_FUEL       int64
# PROP_AGE             int64
# PROP_TYPE            int64
# FLOOR_AREA_BAND      int64
# EE_BAND              int64
# LOFT_DEPTH           int64
# WALL_CONS            int64
# CWI                float64
# CWI_YEAR           float64
# LI                 float64
# LI_YEAR            float64
# BOILER             float64
# BOILER_YEAR        float64
# gcons              float64
# year                 int64
# econs              float64
# dtype: object

# %%
# groupby properties by HH_ID and see average
ldn_HH = ldn.groupby('HH_ID').mean()
ldn.head()
# Out:
#        IMD_ENG  E7Flag2012  MAIN_HEAT_FUEL  PROP_AGE  PROP_TYPE  \
# HH_ID
# 1          1.0         NaN             1.0     101.0      104.0
# 9          4.0         1.0             1.0     102.0      102.0
# 11         2.0         NaN             1.0     101.0      103.0
# 36         4.0         NaN             1.0     101.0      102.0
# 47         1.0         NaN             1.0     106.0      106.0
#
#        FLOOR_AREA_BAND  EE_BAND  LOFT_DEPTH  WALL_CONS  CWI  CWI_YEAR  LI  \
# HH_ID
# 1                  4.0      3.0         2.0        2.0  NaN       NaN NaN
# 9                  3.0      3.0         1.0        1.0  NaN       NaN NaN
# 11                 2.0      3.0         1.0        2.0  NaN       NaN NaN
# 36                 3.0      4.0         2.0        2.0  NaN       NaN NaN
# 47                 2.0      2.0        99.0        1.0  NaN       NaN NaN
#
#        LI_YEAR  BOILER  BOILER_YEAR         gcons    year     econs
# HH_ID
# 1          NaN     NaN          NaN  23012.500000  2008.5  10037.50
# 9          NaN     NaN          NaN  32875.000000  2008.5   6931.25
# 11         NaN     NaN          NaN  20362.500000  2008.5   4087.50
# 36         NaN     NaN          NaN  27125.000000  2008.5   6318.75
# 47         NaN     NaN          NaN   6942.857143  2009.0   1850.00

# %%
# correlation between building age and gas consumption? - 101=before 1930 etc...

from matplotlib import pyplot as plt
import seaborn as sns

sns.lmplot(x='PROP_AGE', y='gcons', data=ldn)
plt.show()

# %%
# less correlation with electricity
sns.lmplot(x='PROP_AGE', y='econs', data=ldn)
plt.show()

# %%
ldn['combinedcons']=ldn.gcons+ldn.econs
ldn.head()
# Out:
#        IMD_ENG  E7Flag2012  MAIN_HEAT_FUEL  PROP_AGE  PROP_TYPE  \
# HH_ID
# 1          1.0         NaN             1.0     101.0      104.0
# 9          4.0         1.0             1.0     102.0      102.0
# 11         2.0         NaN             1.0     101.0      103.0
# 36         4.0         NaN             1.0     101.0      102.0
# 47         1.0         NaN             1.0     106.0      106.0
#
#        FLOOR_AREA_BAND  EE_BAND  LOFT_DEPTH  WALL_CONS  CWI  CWI_YEAR  LI  \
# HH_ID
# 1                  4.0      3.0         2.0        2.0  NaN       NaN NaN
# 9                  3.0      3.0         1.0        1.0  NaN       NaN NaN
# 11                 2.0      3.0         1.0        2.0  NaN       NaN NaN
# 36                 3.0      4.0         2.0        2.0  NaN       NaN NaN
# 47                 2.0      2.0        99.0        1.0  NaN       NaN NaN
#
#        LI_YEAR  BOILER  BOILER_YEAR         gcons    year     econs  \
# HH_ID
# 1          NaN     NaN          NaN  23012.500000  2008.5  10037.50
# 9          NaN     NaN          NaN  32875.000000  2008.5   6931.25
# 11         NaN     NaN          NaN  20362.500000  2008.5   4087.50
# 36         NaN     NaN          NaN  27125.000000  2008.5   6318.75
# 47         NaN     NaN          NaN   6942.857143  2009.0   1850.00
#
#        combinedcons
# HH_ID
# 1      33050.000000
# 9      39806.250000
# 11     24450.000000
# 36     33443.750000
# 47      8792.857143

# %%
# combined consumption?
sns.lmplot(x='PROP_AGE', y='combinedcons', data=ldn)
plt.show()

# %%
# other parameters
# FLOOR_AREA_BAND, 

v = ['PROP_TYPE', 'FLOOR_AREA_BAND', 'EE_BAND', 'LOFT_DEPTH', 'BOILER_YEAR', 'IMD_ENG']
n = 5
sns.lmplot(x=v[n], y='combinedcons', data=ldn)
plt.show()
